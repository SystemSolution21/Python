# %% [markdown]
# <a href="https://colab.research.google.com/github/SystemSolution21/Python/blob/main/yakthung_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS
# !pip install IPython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.5 MB/s eta 0:00:00
# ...

# %%
# Import the required module for text
# to speech conversion
from gtts import gTTS

# This module is imported so that we can
# play the converted audio
import os

# The text that you want to convert to audio
#mytext = 'Welcome to text to speech conversion apps!'
mydict: dict = {"ᤁᤧᤖᤧᤰᤀᤥ": "केरेक्ओ", "ᤏᤥᤛᤧᤴ": "नोसेन्", "ᤘᤠᤖᤥ": "वारो"}
mytext = [item for item in mydict.values()]
mytext = " ".join(mytext)
print(mytext)

# Language in which you want to convert
# language = "en"
language = "hi"

# Passing the text and language to the engine,
# here we have marked slow=False. Which tells
# the module that the converted audio should
# have a high speed
myobj = gTTS(text=mytext, lang=language, slow=False)

# Saving the converted audio in a mp3 file named
# welcome
myobj.save("yakthung_greeting.mp3")

# Playing the converted file
os.system("start yakthung_greeting.mp3")
# Out:
# केरेक्ओ नोसेन् वारो
# 32512

# %%
# Import the required module for text
# to speech conversion
from gtts import gTTS
from IPython import display

# This module is imported so that we can
# play the converted audio
import os

# The text that you want to convert to audio
#mytext = 'Welcome to text to speech conversion apps!'
mydict: dict = {"ᤀ": "अ", "ᤀᤠ": "आ", "ᤀᤡ": "इ",
                "ᤀᤢ": "उ", "ᤀᤣ": "ए", "ᤀᤤ": "ऐ",
                "ᤀᤥ": "ओ", "ᤀᤦ": "औ", "ᤀᤧ": "ऐ"}
mytext = [item for item in mydict.values()]
mytext = ' '.join(mytext)
print(mytext)

# Language in which you want to convert
language = 'hi'

# Passing the text and language to the engine,
# here we have marked slow=False. Which tells
# the module that the converted audio should
# have a high speed
myobj = gTTS(text=mytext, lang=language, slow=True)

# Saving the converted audio in a mp3 file
myobj.save("yakthung_kubungsak.mp3")

# Playing the converted file
file= "./yakthung_kubungsak.mp3"
display.Audio(file)
# Out:
# अ आ इ उ ए ऐ ओ औ ऐ
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image

# Open the image file
image_path = "./IMG_0312.jpeg"
img = Image.open(image_path)

# Display the image
img.show()

# %%
# encoding decoding
txt_1: chr = "ᤀ"
print(txt_1.encode("utf-8"))

txt_1: bytes = b'\xe1\xa4\x80'
print(txt_1.decode("utf-8"))

txt_2: bytes = b'\xe1\xa4\xa0'
print(txt_2.decode("utf-8"))

txt_com: bytes = b'\xe1\xa4\x80'+ b'\xe1\xa4\xa0'
print(txt_com.decode("utf-8"))
# Out:
# b'\xe1\xa4\x80'
# ᤀ
# ᤠ
# ᤀᤠ
