# %% [markdown]
# <a href="https://colab.research.google.com/github/SystemSolution21/Python/blob/main/sequence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile fibonacci.cpp
# #include <iostream>
# using namespace std;
#
# void fibonacci(int num){
#     int a = 0, b = 1, sum = 0;
#     cout << "fibonacci sequence of " << num << ":" <<endl;
#     while (sum <= num){
# //        cout << sum << endl;
#         cout << sum << " ";
#         sum = a + b;
#         b = a;
#         a = sum;
#     }
# }
#
# int main(){
#     fibonacci(10);
#     return 0;
# }
# Out:
# Writing fibonacci.cpp

# %%
# %%bash
# g++ fibonacci.cpp -o fibonacci

# %%
# %%bash
# ./fibonacci
# Out:
# fibonacci sequence of 10:
# 0 1 1 2 3 5 8

# %%
# fibonacci series
def fibonacci(n) -> list[int]:
    """Return a list of fibonacci series up to n."""
    result = []
    a, b = 0, 1
    while a <= n:
        result.append(a)
        a, b = b, a + b
    return result


def main() -> None:
    while (num := input("Input number to generate fibonacci series or 'q' to quit: "))!='q':
        if num.isdigit():
            n = int(num)
            f = fibonacci(n)
            print(f)
            print(sum(f))
        else:
            print("Invalid Input!")


if __name__ == "__main__":
    main()
# Out:
# Input number to generate fibonacci series or 'q' to quit: q

# %%
# sum of fibonacci series
def fibonacci(n) -> int:
    """Return sum of n fibonacci series."""
    if n < 2:
        return n
    return fibonacci(n-1) + fibonacci(n-2)


def main() -> None:
    f = fibonacci(10)
    print(f)


if __name__ == "__main__":
    main()
# Out:
# 55

# %%
from functools import cache

#2 Generate fibonacci sequence nunber of items enter
@cache
def fib(n) -> int:

    f: int = int(0)

    if n < 2:
        print(n)
        return n

    f = fib(n-1) + fib(n-2)
    print(f)
    return f
    #return fib(n-1) + fib(n-2)


def main() -> None:

    n: int = int(input("Enter number of items to generate fibocacci sequence: "))
    fib(n)


if __name__ == '__main__':
    main()
# Out:
# Enter number of items to generate fibocacci sequence: 3
# 1
# 0
# 1
# 2
